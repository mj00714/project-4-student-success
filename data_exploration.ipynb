# %%
# Import MongoClient
from pymongo import MongoClient
import pandas as pd

# %%
# Create MongoClient instance 
mongo = MongoClient(port=27017)
# Confirm creation
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'epa', 'fruits_db', 'local', 'met', 'student_success', 'travel_db']

# %%
# Assign the database to a variable for easier access
student_db = mongo["student_success"]
print(student_db.list_collection_names())
# Out:
# ['most_recent_cohorts_institution']

# %%
# Pull the csv file to view
most_recent_cohort_df = pd.read_csv("Most-Recent-Cohorts-Institution.csv")
most_recent_cohort_df.head()
# Out:
# C:\Users\jenna\AppData\Local\Temp\ipykernel_26604\569133944.py:2: DtypeWarning: Columns (9,1347,1350,1352,1416,1418,1424,1425,1429,1430,1431,1432,1433,1434,1435,1436,1437,1438,1439,1513,1514,1535,1536,1537,1538,1539,1553,1625,1626,1627,1628,1633,1634,1640,1641,1689,1690,1691,1692,1693,1694,1695,1696,1697,1698,1699,1700,1701,1702,1703,1704,1705,1706,1707,1708,1719,1720,1721,1722,1723,1767,1768,1769,1770,1771,1772,1773,1774,1775,1776,1777,1778,1779,1780,1781,1782,1783,1784,1785,1786,1793,1794,2186,2187,2213,2214,2305,2306,2307,2308,2309,2310,2311,2312,2313,2314,2315,2316,2317,2318,2319,2320,2321,2322,2323,2324,2325,2326,2327,2328,2329,2330,2331,2332,2333,2334,2335,2336,2337,2338,2339,2340,2768) have mixed types. Specify dtype option on import or set low_memory=False.
#   most_recent_cohort_df = pd.read_csv("Most-Recent-Cohorts-Institution.csv")
#    UNITID      OPEID   OPEID6                               INSTNM  \
# 0  100654   100200.0   1002.0             Alabama A & M University
# ...

# %%
most_recent_cohort_df.info()
columns_list = list(most_recent_cohort_df.columns)
columns_list
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6543 entries, 0 to 6542
# Columns: 3024 entries, UNITID to BBRR4_PP_NOMALE_DISCHARGE
# dtypes: float64(637), int64(14), object(2373)
# memory usage: 151.0+ MB
# ['UNITID',
#  'OPEID',
#  'OPEID6',
#  'INSTNM',
#  'CITY',
#  'STABBR',
#  'ZIP',
#  'ACCREDAGENCY',
#  'INSTURL',
#  'NPCURL',
#  'SCH_DEG',
#  'HCM2',
#  'MAIN',
#  'NUMBRANCH',
#  'PREDDEG',
#  'HIGHDEG',
#  'CONTROL',
#  'ST_FIPS',
#  'REGION',
#  'LOCALE',
#  'LOCALE2',
#  'LATITUDE',
#  'LONGITUDE',
#  'CCBASIC',
#  'CCUGPROF',
#  'CCSIZSET',
#  'HBCU',
#  'PBI',
#  'ANNHI',
#  'TRIBAL',
#  'AANAPII',
#  'HSI',
#  'NANTI',
#  'MENONLY',
#  'WOMENONLY',
#  'RELAFFIL',
#  'ADM_RATE',
#  'ADM_RATE_ALL',
#  'SATVR25',
#  'SATVR75',
#  'SATMT25',
#  'SATMT75',
#  'SATWR25',
#  'SATWR75',
#  'SATVRMID',
#  'SATMTMID',
#  'SATWRMID',
#  'ACTCM25',
#  'ACTCM75',
#  'ACTEN25',
#  'ACTEN75',
#  'ACTMT25',
#  'ACTMT75',
#  'ACTWR25',
#  'ACTWR75',
#  'ACTCMMID',
#  'ACTENMID',
# ...

# %%
# Filter the dataframe to select obly the variables you want 
cluster_variables_df = most_recent_cohort_df[['UGDS_WHITE','UGDS_BLACK','UGDS_HISP','UGDS_ASIAN',
                                                'UGDS_AIAN','UGDS_NHPI','UGDS_2MOR','UGDS_NRA',
                                                'UGDS_UNKN','UGDS_WHITENH','UGDS_BLACKNH','UGDS_API',
                                                'UGDS_AIANOLD','UGDS_HISPOLD','UG_NRA','UG_UNKN','UG_WHITENH','UG_BLACKNH',
                                                'NPT4_PUB','NPT4_PRIV','COSTT4_A','AVGFACSAL','C150_4']]
cluster_variables_df.describe()
cluster_variables_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6543 entries, 0 to 6542
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UGDS_WHITE    5769 non-null   float64
#  1   UGDS_BLACK    5769 non-null   float64
#  2   UGDS_HISP     5769 non-null   float64
#  3   UGDS_ASIAN    5769 non-null   float64
#  4   UGDS_AIAN     5769 non-null   float64
#  5   UGDS_NHPI     5769 non-null   float64
#  6   UGDS_2MOR     5769 non-null   float64
#  7   UGDS_NRA      5769 non-null   float64
#  8   UGDS_UNKN     5769 non-null   float64
#  9   UGDS_WHITENH  0 non-null      float64
#  10  UGDS_BLACKNH  0 non-null      float64
#  11  UGDS_API      0 non-null      float64
#  12  UGDS_AIANOLD  0 non-null      float64
#  13  UGDS_HISPOLD  0 non-null      float64
#  14  UG_NRA        0 non-null      float64
#  15  UG_UNKN       0 non-null      float64
#  16  UG_WHITENH    0 non-null      float64
# ...

# %%
# Search for rows (axis=1) where any value in a column is NaN
null_cluster_df = cluster_variables_df[cluster_variables_df.isna().any(axis=1)]
null_cluster_df
# Out:
#       UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# 0         0.0184      0.8978     0.0114      0.0014     0.0027     0.0010
# 1         0.5297      0.2458     0.0669      0.0767     0.0021     0.0004
# 2         0.2470      0.6932     0.0438      0.0000     0.0000     0.0040
# 3         0.7196      0.0871     0.0610      0.0357     0.0080     0.0012
# 4         0.0152      0.9259     0.0129      0.0020     0.0017     0.0014
# ...          ...         ...        ...         ...        ...        ...
# 6538         NaN         NaN        NaN         NaN        NaN        NaN
# 6539         NaN         NaN        NaN         NaN        NaN        NaN
# 6540         NaN         NaN        NaN         NaN        NaN        NaN
# 6541         NaN         NaN        NaN         NaN        NaN        NaN
# 6542         NaN         NaN        NaN         NaN        NaN        NaN
#
#       UGDS_2MOR  UGDS_NRA  UGDS_UNKN  UGDS_WHITENH  ...  UGDS_HISPOLD  UG_NRA  \
# ...
